# %%
# installing required libraries in my_env
# %pip install langchain==0.1.11 gradio==5.23.2 transformers==4.38.2 bs4==0.0.2 requests==2.31.0 torch==2.2.1
# Out:
# Collecting langchain==0.1.11
#   Downloading langchain-0.1.11-py3-none-any.whl.metadata (13 kB)
# Collecting gradio==5.23.2
#   Downloading gradio-5.23.2-py3-none-any.whl.metadata (16 kB)
# Collecting transformers==4.38.2
#   Downloading transformers-4.38.2-py3-none-any.whl.metadata (130 kB)
# Requirement already satisfied: bs4==0.0.2 in e:\machine learning\.venv\lib\site-packages (0.0.2)
# Collecting requests==2.31.0
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting torch==2.2.1
#   Downloading torch-2.2.1-cp312-cp312-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: PyYAML>=5.3 in e:\machine learning\.venv\lib\site-packages (from langchain==0.1.11) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in e:\machine learning\.venv\lib\site-packages (from langchain==0.1.11) (2.0.40)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain==0.1.11)
#   Downloading aiohttp-3.11.17-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain==0.1.11)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in e:\machine learning\.venv\lib\site-packages (from langchain==0.1.11) (1.33)
# Collecting langchain-community<0.1,>=0.0.25 (from langchain==0.1.11)
#   Downloading langchain_community-0.0.38-py3-none-any.whl.metadata (8.7 kB)
# Collecting langchain-core<0.2,>=0.1.29 (from langchain==0.1.11)
#   Downloading langchain_core-0.1.53-py3-none-any.whl.metadata (5.9 kB)
# Collecting langchain-text-splitters<0.1,>=0.0.1 (from langchain==0.1.11)
#   Downloading langchain_text_splitters-0.0.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.1.11)
#   Downloading langsmith-0.1.147-py3-none-any.whl.metadata (14 kB)
# Collecting numpy<2,>=1 (from langchain==0.1.11)
#   Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl.metadata (61 kB)
# Requirement already satisfied: pydantic<3,>=1 in e:\machine learning\.venv\lib\site-packages (from langchain==0.1.11) (2.11.3)
# Collecting tenacity<9.0.0,>=8.1.0 (from langchain==0.1.11)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==5.23.2)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (4.9.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.115.12)
# Requirement already satisfied: ffmpy in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.5.0)
# Requirement already satisfied: gradio-client==1.8.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (1.8.0)
# Requirement already satisfied: groovy~=0.1 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.30.2)
# Requirement already satisfied: jinja2<4.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (3.0.2)
# Requirement already satisfied: orjson~=3.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (3.10.16)
# Requirement already satisfied: packaging in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (24.2)
# Requirement already satisfied: pandas<3.0,>=1.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (2.2.3)
# Requirement already satisfied: pillow<12.0,>=8.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (11.0.0)
# Requirement already satisfied: pydub in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.0.20)
# Requirement already satisfied: ruff>=0.9.3 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.11.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.15.2)
# Requirement already satisfied: typing-extensions~=4.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (4.13.1)
# Requirement already satisfied: uvicorn>=0.14.0 in e:\machine learning\.venv\lib\site-packages (from gradio==5.23.2) (0.34.2)
# Requirement already satisfied: filelock in e:\machine learning\.venv\lib\site-packages (from transformers==4.38.2) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in e:\machine learning\.venv\lib\site-packages (from transformers==4.38.2) (2024.11.6)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.38.2)
#   Downloading tokenizers-0.15.2-cp312-none-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: safetensors>=0.4.1 in e:\machine learning\.venv\lib\site-packages (from transformers==4.38.2) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in e:\machine learning\.venv\lib\site-packages (from transformers==4.38.2) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in e:\machine learning\.venv\lib\site-packages (from bs4==0.0.2) (4.13.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\machine learning\.venv\lib\site-packages (from requests==2.31.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in e:\machine learning\.venv\lib\site-packages (from requests==2.31.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\machine learning\.venv\lib\site-packages (from requests==2.31.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\machine learning\.venv\lib\site-packages (from requests==2.31.0) (2025.1.31)
# Requirement already satisfied: sympy in e:\machine learning\.venv\lib\site-packages (from torch==2.2.1) (1.13.1)
# Requirement already satisfied: networkx in e:\machine learning\.venv\lib\site-packages (from torch==2.2.1) (3.4.2)
# Requirement already satisfied: fsspec in e:\machine learning\.venv\lib\site-packages (from torch==2.2.1) (2025.3.2)
# Requirement already satisfied: websockets<16.0,>=10.0 in e:\machine learning\.venv\lib\site-packages (from gradio-client==1.8.0->gradio==5.23.2) (15.0.1)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: attrs>=17.3.0 in e:\machine learning\.venv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11) (25.3.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11)
#   Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11)
#   Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11)
#   Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.11)
#   Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata (74 kB)
# Requirement already satisfied: sniffio>=1.1 in e:\machine learning\.venv\lib\site-packages (from anyio<5.0,>=3.0->gradio==5.23.2) (1.3.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.11)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.11)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: httpcore==1.* in e:\machine learning\.venv\lib\site-packages (from httpx>=0.24.1->gradio==5.23.2) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\machine learning\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.24.1->gradio==5.23.2) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\machine learning\.venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.11) (3.0.0)
# Collecting packaging (from gradio==5.23.2)
#   Downloading packaging-23.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in e:\machine learning\.venv\lib\site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.11) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\machine learning\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio==5.23.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\machine learning\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio==5.23.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in e:\machine learning\.venv\lib\site-packages (from pandas<3.0,>=1.0->gradio==5.23.2) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\machine learning\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in e:\machine learning\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.11) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in e:\machine learning\.venv\lib\site-packages (from pydantic<3,>=1->langchain==0.1.11) (0.4.0)
# Requirement already satisfied: greenlet>=1 in e:\machine learning\.venv\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain==0.1.11) (3.2.0)
# Requirement already satisfied: colorama in e:\machine learning\.venv\lib\site-packages (from tqdm>=4.27->transformers==4.38.2) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in e:\machine learning\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio==5.23.2) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in e:\machine learning\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio==5.23.2) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in e:\machine learning\.venv\lib\site-packages (from typer<1.0,>=0.12->gradio==5.23.2) (14.0.0)
# Requirement already satisfied: soupsieve>1.2 in e:\machine learning\.venv\lib\site-packages (from beautifulsoup4->bs4==0.0.2) (2.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\machine learning\.venv\lib\site-packages (from sympy->torch==2.2.1) (1.3.0)
# Requirement already satisfied: six>=1.5 in e:\machine learning\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.0->gradio==5.23.2) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\machine learning\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.23.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\machine learning\.venv\lib\site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio==5.23.2) (2.19.1)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.11)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: mdurl~=0.1 in e:\machine learning\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0,>=0.12->gradio==5.23.2) (0.1.2)
# Downloading langchain-0.1.11-py3-none-any.whl (807 kB)
#    ---------------------------------------- 0.0/807.5 kB ? eta -:--:--
#    --------------------------------------- 807.5/807.5 kB 11.6 MB/s eta 0:00:00
# Downloading gradio-5.23.2-py3-none-any.whl (51.3 MB)
#    ---------------------------------------- 0.0/51.3 MB ? eta -:--:--
#    ------ --------------------------------- 8.1/51.3 MB 38.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 30.1/51.3 MB 70.8 MB/s eta 0:00:01
#    ---------------------------------------  51.1/51.3 MB 85.6 MB/s eta 0:00:01
#    ---------------------------------------- 51.3/51.3 MB 77.7 MB/s eta 0:00:00
# Downloading transformers-4.38.2-py3-none-any.whl (8.5 MB)
#    ---------------------------------------- 0.0/8.5 MB ? eta -:--:--
#    ---------------------------------------- 8.5/8.5 MB 88.1 MB/s eta 0:00:00
# Downloading requests-2.31.0-py3-none-any.whl (62 kB)
# Downloading torch-2.2.1-cp312-cp312-win_amd64.whl (198.5 MB)
#    ---------------------------------------- 0.0/198.5 MB ? eta -:--:--
#    ---- ---------------------------------- 24.1/198.5 MB 117.5 MB/s eta 0:00:02
#    --------- ----------------------------- 49.3/198.5 MB 116.2 MB/s eta 0:00:02
#    -------------- ------------------------ 72.9/198.5 MB 116.2 MB/s eta 0:00:02
#    ------------------ -------------------- 96.5/198.5 MB 116.2 MB/s eta 0:00:01
#    ----------------------- -------------- 121.4/198.5 MB 115.7 MB/s eta 0:00:01
#    --------------------------- ---------- 145.0/198.5 MB 115.8 MB/s eta 0:00:01
#    -------------------------------- ----- 170.1/198.5 MB 116.9 MB/s eta 0:00:01
#    -------------------------------------  195.0/198.5 MB 116.5 MB/s eta 0:00:01
#    -------------------------------------  198.4/198.5 MB 116.4 MB/s eta 0:00:01
#    -------------------------------------- 198.5/198.5 MB 104.8 MB/s eta 0:00:00
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading aiohttp-3.11.17-cp312-cp312-win_amd64.whl (439 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading langchain_community-0.0.38-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 117.7 MB/s eta 0:00:00
# Downloading langchain_core-0.1.53-py3-none-any.whl (303 kB)
# Downloading langchain_text_splitters-0.0.2-py3-none-any.whl (23 kB)
# Downloading langsmith-0.1.147-py3-none-any.whl (311 kB)
# Downloading numpy-1.26.4-cp312-cp312-win_amd64.whl (15.5 MB)
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 15.5/15.5 MB 97.2 MB/s eta 0:00:00
# Downloading packaging-23.2-py3-none-any.whl (53 kB)
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Downloading tokenizers-0.15.2-cp312-none-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 59.9 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl (120 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl (38 kB)
# Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl (44 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl (92 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: tenacity, requests, propcache, packaging, numpy, mypy-extensions, multidict, frozenlist, aiohappyeyeballs, aiofiles, yarl, typing-inspect, torch, marshmallow, aiosignal, tokenizers, langsmith, dataclasses-json, aiohttp, transformers, langchain-core, gradio, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.1.2
#     Uninstalling tenacity-9.1.2:
#       Successfully uninstalled tenacity-9.1.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.2
#     Uninstalling packaging-24.2:
#       Successfully uninstalled packaging-24.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 24.1.0
#     Uninstalling aiofiles-24.1.0:
#       Successfully uninstalled aiofiles-24.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.21.1
#     Uninstalling tokenizers-0.21.1:
#       Successfully uninstalled tokenizers-0.21.1
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.32
#     Uninstalling langsmith-0.3.32:
#       Successfully uninstalled langsmith-0.3.32
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.51.3
#     Uninstalling transformers-4.51.3:
#       Successfully uninstalled transformers-4.51.3
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.54
#     Uninstalling langchain-core-0.3.54:
#       Successfully uninstalled langchain-core-0.3.54
#   Attempting uninstall: gradio
#     Found existing installation: gradio 5.25.2
#     Uninstalling gradio-5.25.2:
#       Successfully uninstalled gradio-5.25.2
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.8
#     Uninstalling langchain-text-splitters-0.3.8:
#       Successfully uninstalled langchain-text-splitters-0.3.8
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.23
#     Uninstalling langchain-0.3.23:
#       Successfully uninstalled langchain-0.3.23
# Successfully installed aiofiles-23.2.1 aiohappyeyeballs-2.6.1 aiohttp-3.11.17 aiosignal-1.3.2 dataclasses-json-0.6.7 frozenlist-1.6.0 gradio-5.23.2 langchain-0.1.11 langchain-community-0.0.38 langchain-core-0.1.53 langchain-text-splitters-0.0.2 langsmith-0.1.147 marshmallow-3.26.1 multidict-6.4.3 mypy-extensions-1.0.0 numpy-1.26.4 packaging-23.2 propcache-0.3.1 requests-2.31.0 tenacity-8.5.0 tokenizers-0.15.2 torch-2.2.1 transformers-4.38.2 typing-inspect-0.9.0 yarl-1.20.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'E:\Machine Learning\.venv\Lib\site-packages\~-mpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'E:\Machine Learning\.venv\Lib\site-packages\~-mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'E:\Machine Learning\.venv\Lib\site-packages\~orch'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'E:\Machine Learning\.venv\Lib\site-packages\~okenizers'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0+cu124, but you have torch 2.2.1 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0+cu124, but you have torch 2.2.1 which is incompatible.
